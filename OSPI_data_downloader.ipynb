# %% [markdown]
# # Dowloading multiple S275 files from state web-site

# %%
import urllib
import os
import urllib.request
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Single file case

# %%
file_name ='C:/Users/jhernandez/Documents/S275/data_test.accdb'# change where this file gets dumped into 
url = 'http://www.k12.wa.us/safs/PUB/PER/1516/2015-2016_Final_S-275_Personnel_Database.accdb'

# %%
# Download the file from `url` and save it locally under `file_name`:
urllib.request.urlretrieve(url, file_name)
# Out:
# ('C:/Users/jhernandez/Documents/S275/data_test.accdb',
#  <http.client.HTTPMessage at 0x16b0d755c88>)

# %% [markdown]
# ## Multiple file case using Beautiful Soup

# %%
data_url = "http://www.k12.wa.us/safs/"
archive_url = "http://www.k12.wa.us/safs/db.asp"

# %% [markdown]
# ### Create response object

# %%
r = requests.get(archive_url)

# %% [markdown]
# ### create bs object

# %%
soup = BeautifulSoup(r.content,'html5lib')

# %% [markdown]
# #### Look at soup object same as "inspect element in chrome"

# %%
#print(soup)
# Out:
# <html xmlns:m="http://schemas.microsoft.com/office/2004/12/omml" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:v="urn:schemas-microsoft-com:vml"><head>
# <title>SAFS Access Databases and Excel Files</title>
# <meta content="Superintendent of Public Instruction School Apportionment and Financial Services" name="title"/>
# <meta content="This page provides links to the accounting manual published by School Financial Services for school districts in Washington State." name="description"/>
# <meta content="State of Washington" name="originatorJurisdiction"/>
# <meta content="Superintendent of Public Instructions" name="originatorDepartment"/>
# <meta content="School Apportionment &amp; Financial Services" name="originatorOffice"/>
# <meta content="current" name="timePeriodTextual"/>
# <meta content="State government" name="govType"/>
# <meta content="account manual, expenditure codes, revenue codes" name="keywords"/>
# <meta content="Accounting Manual, School Financial Services" name="subjects"/>
# <meta content="July 4, 2001" name="dateofLastModification"/>
# <meta content="Washington Superintendent of Public Instruction SAFS" name="contactOrganization"/>
# <meta content="Old Capitol Building" name="contactStreetAddress1"/>
# <meta content="PO Box 47200 " name="contactStreetAddress2"/>
# <meta content="Olympia" name="contactCity"/>
# <meta content="WA" name="contactState"/>
# <meta content="98504-7200" name="contactZipcode"/>
# <meta content="Web page" name="medium"/>
# <base target="_top"/>
# <style type="text/css">
#  @import url('includes/SAFStyle.css');
#  p.MsoNormal
# 	{margin-bottom:.0001pt;
# 	font-size:11.0pt;
# 	font-family:"Calibri","sans-serif";
# 		margin-left: 0in;
# 	margin-right: 0in;
# 	margin-top: 0in;
# }
# .newStyle1 {
# 				background-color: #C0C0C0;
# 				color: #FFFFFF;
# 				font-style: normal;
# 				font-variant: small-caps;
# }
# .style1 {
# 				background-color: #99CCFF;
# 				color: #FFFFFF;
# 				font-style: normal;
# 				font-variant: small-caps;
# 				font-size: larger;
# }
# .style2 {
# 				border-width: 0px;
# }
# .style3 {
# 				background-color: #FFFFFF;
# }
# .style4 {
# 				font-weight: bold;
# }
# .style5 {
# 	font-family: Verdana;
# 	font-size: x-small;
# }
# </style>
# <script language="JavaScript">
#
# <!-- This script and many more are available online from -->
# <!-- The JavaScript Source!! http://javascript.internet.com -->
#
# <!-- Begin
# if (location.href.indexOf("tsearchleft.asp") != -1){
# var strURLPrefix="http://www.k12.wa.us";
# }
# else {
# var strURLPrefix="";
# }
# // End -->
# </script></head>
#
# <body alink="#000000" leftmargin="0" link="#000000" marginheight="0" marginwidth="0" onload="CSScriptInit();" topmargin="0" vlink="#B10000"><csscriptdict>
# <script><!--
# CSStopExecution = false;
# CSInit = new Array;
# function CSScriptInit() {
# idxArray = new Array;
# for(var i=0;i<CSInit.length;i++)
# 	idxArray[i] = i;
# CSAction2(CSInit, idxArray);
# }
# CSAg = window.navigator.userAgent; CSBVers = parseInt(CSAg.charAt(CSAg.indexOf("/")+1),10);
# function IsIE() { return CSAg.indexOf("MSIE") > 0;}
# function CSIEStyl(s) { return document.all.tags("div")[s].style; }
# function CSNSStyl(s) { return CSFindElement(s,0); }
# function CSFindElement(n,ly) { if (CSBVers < 4) return document[n];
# 	var curDoc = ly ? ly.document : document; var elem = curDoc[n];
# 	if (!elem) { for (var i=0;i<curDoc.layers.length;i++) {
# 		elem = CSFindElement(n,curDoc.layers[i]); if (elem) return elem; }}
# 	return elem;
# }
# function CSURLPopupShow(formName, popupName, target) {
# 	var form  = CSFindElement(formName);
# 	var popup = form.elements[popupName];
# 	window.open(popup.options[popup.selectedIndex].value, target);
# 	popup.selectedIndex = 0;
# }
# function CSButtonReturn () {
# 	var bAgent = window.navigator.userAgent;
# 	var bAppName = window.navigator.appName;
# 	if ((bAppName.indexOf("Explorer") >= 0) && (bAgent.indexOf("Mozilla/3") >= 0) && (bAgent.indexOf("Mac") >= 0))
# 		return false; // follow link
# 	else return true; // follow link
# }
# CSIm = new Object();
# function CSIShow(n,i) {
# 	if (document.images) {
# 		if (CSIm[n]) {
# 			var img = (!IsIE()) ? CSFindElement(n,0) : document[n];
# 			if (img && typeof(CSIm[n][i].src) != "undefined") {img.src = CSIm[n][i].src;}
# 			if(i != 0)
# 				self.status = CSIm[n][3];
# 			else
# 				self.status = " ";
# 			return true;
# 		}
# 	}
# 	return false;
# }
# function CSILoad(action) {
# 	im = action[1];
# 	if (document.images) {
# 		CSIm[im] = new Object();
# 		for (var i=2;i<5;i++) {
# 			if (action[i] != '') { CSIm[im][i-2] = new Image(); CSIm[im][i-2].src = action[i]; }
# 			else CSIm[im][i-2] = 0;
# 		}
# 		CSIm[im][3] = action[5];
# 	}
# }
# CSStopExecution = false;
#
# function CSAction(array) {
# 	return CSAction2(CSAct, array);
# }
#
# function CSAction2(fct, array) {
# 	var result;
# 	for (var i=0;i<array.length;i++) {
# 		if(CSStopExecution) return false;
# 		var actArray = fct[array[i]];
# 		var tempArray = new Array;
# 		for(var j=1;j<actArray.length;j++) {
# 			if((actArray[j] != null) && (typeof(actArray[j]) == "object") && (actArray[j].length == 2)) {
# 				if(actArray[j][0] == "VAR") {
# 					tempArray[j] = CSStateArray[actArray[j][1]];
# 				}
# 				else {
# 					if(actArray[j][0] == "ACT") {
# 						tempArray[j] = CSAction(new Array(new String(actArray[j][1])));
# 					}
# 				else
# 					tempArray[j] = actArray[j];
# 				}
# 			}
# 			else
# 				tempArray[j] = actArray[j];
# 		}
# 		result = actArray[0](tempArray);
# 	}
# 	return result;
# }
# CSAct = new Object;
#
# // --></script>
# </csscriptdict>
#
#
#
#
#
#
#
#
# <table border="0" cellpadding="0" cellspacing="0" height="90" width="100%">
#   <tbody><tr valign="top">
#     <td bgcolor="#336699"><a href="/"><img alt="OSPI Homepage" border="0" src="/images/header.gif"/></a></td>
#     <td bgcolor="#336699" height="90" width="100%"> </td>
# 	<td>
# <!-- Set the Image that will appear in the banner -->
#
# 	    </td><td align="right"><map name="FPMap1">
# <area coords="94, 5, 164, 30" href="/" shape="rect"/>
# </map>
# <img alt="background" border="0" height="90" src="/images/SectionPhotos/image6.gif" usemap="#FPMap1" width="253"/></td>
#
#
#   </tr>
# </tbody></table>
#
#
#
# <table border="0" width="100%">
#     <tbody><tr>
#     	<td bgcolor="#061E50" height="10"> </td>
#     </tr>
# </tbody></table>
#
#
#
# <link href="/global.css" rel="stylesheet" type="text/css"/>
# <link href="/SAFS/script/Style.css" rel="stylesheet" type="text/css"/>
# <script src="/SAFS/script/script.js" type="text/javascript"></script>
#
# 	<style type="text/css">
# @import url('SAFStyle.css');
# </style>
#
#
# 	<table border="0" cellpadding="0" cellspacing="0" width="100%">
#   <tbody><tr valign="top">
#     <td bgcolor="#F1F1F1" valign="top" width="150">
#     		<table border="0" width="150">
# 			<tbody><tr valign="top">
# 				<td width="150">
#
#
# <div class="suckerdiv">
#
#
# <ul id="suckertree1">
# <li><b><a href="/SAFS/default.asp">SAFS Home</a></b></li>
#
#
# <!--instructions-->
#
# 				<li><a href="#">Instructions</a>
# 				 <ul>
# 				  <li><a href="#">ABFR Handbook</a>
# 								  <ul>
# 								  	<li><a href="/safs/INS/ABF/1718/hb.asp">2017-2018</a></li>
# 									<li><a href="/safs/INS/ABF/1617/hb.asp">2016-2017</a></li>
# 								  	<li><a href="/safs/INS/ABF/1516/hb.asp">2015-2016</a></li>
# 								  	<li><a href="/safs/INS/ABF/1415/hb.asp">2014-2015</a></li>
# 								    <li><a href="/safs/INS/ABF/1314/hb.asp">2013-2014</a></li>
# 								    <li><a href="/safs/INS/ABF/1213/hb.asp">2012-2013</a></li>
# 								    <li><a href="/safs/INS/ABF/1112/hb.asp">2011-2012</a></li>
# 								    <li><a href="/safs/INS/ABF/1011/hb.asp">2010-2011</a></li>
# 								    <li><a href="/safs/INS/ABF/0910/hb.asp">2009-2010</a></li>
# 								    <li><a href="/safs/INS/ABF/0809/hb.asp">2008-2009</a></li>
# 								    <li><a href="/safs/INS/ABF/0708/hb.asp">2007-2008</a></li>
# 								    <li><a href="/safs/INS/ABF/0607/hb.asp">2006-2007</a></li>
# 								    <li><a href="/safs/INS/ABF/0506/hb.asp">2005-2006</a></li>
# 								    <li><a href="/safs/INS/ABF/0405/hb.asp">2004-2005</a></li>
# 								    <li><a href="/safs/INS/ABF/0304/hb.asp">2003-2004</a></li>
# 								    <li><a href="/safs/INS/ABF/0203/hb.asp">2002-2003</a></li>
# 								    <li><a href="/safs/INS/ABF/0102/hb.asp">2001-2002</a></li>
#
#
# <li><a href="#">Committees</a>
# 					<ul>
# 				    <li><a href="/safs/PUB/COM/SDAAC.asp">Accounting Advisory Committee</a></li>
# 					</ul>
# </li>
#
# <li><a href="/safs/INS/MIS/help.asp">Helpful Links</a></li>
#
#
# <li><a href="/safs/staff.asp">About Us</a></li>
#
#
# <li><a href="/safs/PUB/PER/K-12SalAllocSchedCIS2016-18.pdf">Salary Allocation Schedules</a></li>
#
#
# <li><a href="https://eds.ospi.k12.wa.us/Login.aspx?ReturnUrl=%2fDefault.aspx">EDS Application</a></li>
#
# </ul>
# </div>
# </td></tr>
# 	</tbody></table>
# 	</td>
# 	<td align="left" width="100%">
# 		<table border="0" bordercolor="#111111" cellpadding="0" cellspacing="0" style="border-collapse: collapse" width="100%">
# 		<tbody><tr><td bgcolor="#F1F1F1" bordercolor="#F1F1F1" width="1">
#
# 	</td>
# 	<td valign="top" width="100%">
# 	</td></tr></tbody></table>
#
#
#
# <p>
# <img border="0" src="/images/sectionimages/safstitle.gif" usemap="#FPMap90"/></p>
#
#
# <!-- BEGIN MAIN CONTENT HERE -->
#
# <table border="0" width="100%">
# 	<tbody><tr>
# 	<td class="ReportTitle"><span style="font-size:12.0pt;color:black">This is
# 	a discrete website provided for knowledgeable  users with the capability  to
# 	work with large amounts of data  in Access and/or Excel.
# 	(Several of these databases are too large for Excel).    Each dataset
# 	requires the user to have firm knowledge of the data fields reported and
# 	their interrelationships to capably work with the data files.  OSPI
# 	does not have the resources to, and cannot, provide support for users that
# 	do not have this prerequisite knowledge. <o:p></o:p></span></td>
# 	</tr>
# 	<tr>
# 	<td class="ReportTitle"> </td>
# 	</tr>
# 	<tr>
# 	<td class="ReportTitle">Databases</td>
# 	</tr>
# 	<tr>
# 	<td class="SubjectTitle12LeftBoldWhiteOnBlack">Access Database Files</td>
# 	</tr>
# 	<tr>
# 	<td>The following files were created in Microsoft Access and contain the raw
# 		data reflected in the F-195, F-196, and S-275 files. Each database has been zipped to conserve
# 		space. The user will need to unzip the files and open the database with the Access program.
# 	</td>
# 	</tr>
# </tbody></table>
#
# <table border="0" width="100%">
# <tbody><tr>
# <td><img class="style2" height="12" src="images/BD14868_.gif" width="12"/></td>
# <td>
# <a href="INS/MIS/2015-16F-196Access.zip">Financial Services Data Base--Microsoft Access FY 2015-2016 F196 - End of Year Financial Data</a>  (Zipped) (Updated 12/22/16) (For further information contact <a href="mailto:ramona.garner@k12.wa.us">Ramona Garner</a> 360-725-6304)
# </td>
# </tr>
# <tr>
# <td><img class="style2" height="12" src="images/BD14868_.gif" width="12"/></td>
# <td>
# <a href="INS/MIS/2014-15FinalF-196AccessDatabase.zip">Financial Services Data Base--Microsoft Access FY 2014-2015 F196 - End of Year Financial Data</a>  (Zipped) (Updated 1/28/16) (For further information contact <a href="mailto:ramona.garner@k12.wa.us">Ramona Garner</a> 360-725-6304)
# </td>
# </tr>
#
#   <tr>
#     <td style="width: 2%" valign="top">
# 	<a href="INS/MIS/aF1961314_WEB-corrected.zip">
# 	<img class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
#     <td width="98%"><b style="font-weight: 400">
# 	<a href="INS/MIS/aF1961314_WEB-corrected.zip">Financial Services Data Base--Microsoft
#     Access FY 2013-14 F196 - End of Year Financial Data</a> (Zipped) (Updated</b>
# 	1/5/15)  (For further
# 	information contact <a href="mailto:ramona.garner@k12.wa.us">Ramona Garner</a> 360-725-6304)
# 	</td>
#   </tr>
#
#
#   <tr>
#     <td style="width: 2%" valign="top">
# 	<img height="12" src="images/BD14868_.gif" width="12"/></td>
#     <td width="98%"><b><a href="INS/MIS/aF1951617.accdb">Financial Services Data Base--Microsoft Access FY 2016-2017 F195 Budget</a> </b>(Posted 1/13/17) (For further information contact
# 	<a href="mailto:mike.dooley@k12.wa.us">Mike Dooley</a> 360-725-6305)</td>
#   </tr>
#
#
#   <tr>
#     <td style="width: 2%" valign="top">
# 	<img height="12" src="images/BD14868_.gif" width="12"/></td>
#     <td width="98%"><a href="INS/MIS/Item%20Number%20Multiple%20Year.mdb">
# 	Financial Services Data - Microsoft Access Multiple Year F-196 Item Numbers</a>
# 	(Posted 5/24/12) (For further information contact
# 	<a href="mailto:ramona.garner@k12.wa.us">Ramona Garner</a> 360-725-6304).</td>
#   </tr>
#
#   <tr>
#     <td style="width: 2%" valign="top">
# 	 </td>
#     <td width="98%"> </td>
#   </tr>
#
# </tbody></table>
#
# <table>
# 	<tbody><tr>
# 	<td>
# 	Preliminary S-275 school personnel data is available around February of the school year
# 	(for example, February 2017 for the 2016-17 school year). Final S-275 school personnel data
# 	is available around November after the end of the school year (for example, November 2016 for
# 	the 2015-16 school year).<br/>
# 	<br/>
# 	The S-275 school personnel data provided is complete with the exception of:<br/>
# 	*Social Security numbers, which are exempt from disclosure per RCW 42.56.250(3); and<br/>
# 	*A very limited number of personnel records, where personal information of crime victims is
# 	protected (Chapter 40.24 RCW) and where the safety of individuals may be endangered.</td>
# 	</tr>
# </tbody></table>
# <table>
# 				<tbody><tr>
# 								<td>
# 								<a href="PUB/PER/1617/2016-2017_Preliminary_S-275_Personnel_Database.accdb">
# 	<img class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1617/2016-2017_Preliminary_S-275_Personnel_Database.accdb">
# 								2016-2017 Preliminary S-275 Personnel Database</a>
# 								(For more information, contact
# 								<a href="mailto:ross.bunda@k12.wa.us?subject=2016-2017 Preliminary S-275 Personnel Database">
# 								Ross Bunda</a>, 360-725-6308) <em>Updated
# 								February 2, 2017</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1516/2015-2016_Final_S-275_Personnel_Database.accdb">
# 	<img class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1516/2015-2016_Final_S-275_Personnel_Database.accdb">
# 								2015-2016 Final S-275 Personnel Database</a>
# 								(For more information, contact
# 								<a href="mailto:ross.bunda@k12.wa.us?subject=2015-2016 Final S-275 Personnel Database">
# 								Ross Bunda</a>, 360-725-6308) <em>Updated
# 								December 6, 2016</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1415/2014-2015S275FinalForPublic.accdb">
# 	<img class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1415/2014-2015S275FinalForPublic.accdb">
# 								2014-2015 Final S-275 Personnel Database</a>
# 								(For more information, contact
# 								<a href="mailto:ross.bunda@k12.wa.us?subject=2014-2015 Final S-275 Personnel Database">
# 								Ross Bunda</a>, 360-725-6308) <em>Updated
# 								December 9, 2015</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1314/2013-2014S275FinalForPublic.mdb">
# 	<img class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1314/2013-2014S275FinalForPublic.mdb">
# 								2013-2014 Final S-275 Personnel Database</a>
# 								(For more information, contact
# 								<a href="mailto:ross.bunda@k12.wa.us?subject=2013-2014 Final S-275 Personnel Database">
# 								Ross Bunda</a>, 360-725-6308) <em>Updated
# 								December 11, 2014</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1213/2012-2013S275FinalForPublic.mdb">
# 	<img class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER
="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/9596/1995-1996S275FinalForPublic.mdb">1995-1996 Final S-275 Personnel Database</a>
# 								(For more information, contact
# 								<a href="mailto:ross.bunda@k12.wa.us">Ross Bunda</a>,
# 								360-725-6308) <em>Updated September 5, 2012</em></td>
# 				</tr>
# 				</tbody></table>
#
# <p><strong class="style1">Adobe PDF Files</strong></p>
# <p class="style5">The following Adobe PDF data files are simplified versions of the S-275 data
# on Washington State school personnel for each school year, sorted by employing
# school district and the person's last name. You can also use the Adobe edit
# feature "Find" (Ctrl+F) to search for individual records. For example, you can
# find records for teacher John Doe with certificate number 123456A by searching
# for "Doe, John" or "doe, john" or "doe, j", or "123456A", and so on.</p>
# <table>
#
# 				<tbody><tr>
# 								<td>
# 								<a href="PUB/PER/1617/Washington_State_School_Personnel_-_School_Year_2016-2017.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1617/Washington_State_School_Personnel_-_School_Year_2016-2017.pdf">
# 								Washington State School Personnel - School Year
# 								2016-2017</a> (pdf) <em>Updated February 2, 2017</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1516/Washington_State_School_Personnel_-_School_Year_2015-2016.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1516/Washington_State_School_Personnel_-_School_Year_2015-2016.pdf">
# 								Washington State School Personnel - School Year
# 								2015-2016</a> (pdf) <em>Updated December 6, 2016</em></td>
# 				</tr>
# <tr>
# 								<td>
# 								<a href="PUB/PER/1415/Washington State School Personnel - School Year 2014-2015.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1415/Washington State School Personnel - School Year 2014-2015.pdf">
# 								Washington State School Personnel - School Year
# 								2014-2015</a> (pdf) <em>Updated December 9, 2015</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1314/Washington State School Personnel - School Year 2013-2014.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1314/Washington State School Personnel - School Year 2013-2014.pdf">
# 								Washington State School Personnel - School Year
# 								2013-2014</a> (pdf) <em>Updated December 11, 2014</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1213/Washington%20State%20School%20Personnel%20-%20School%20Year%202012-2013.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1213/Washington%20State%20School%20Personnel%20-%20School%20Year%202012-2013.pdf">Washington State School Personnel - School Year
# 								2012-2013</a> (pdf) <em>Updated November 4, 2013</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1112/Washington%20State%20School%20Personnel%20-%20School%20Year%202011-2012.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1112/Washington%20State%20School%20Personnel%20-%20School%20Year%202011-2012.pdf">Washington State School Personnel - School Year
# 								2011-2012 </a>(pdf) <em>Updated October 31, 2012</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/1011/Washington%20State%20School%20Personnel%20-%20School%20Year%202010-2011.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/1011/Washington%20State%20School%20Personnel%20-%20School%20Year%202010-2011.pdf">
# 								Washington State School Personnel - School Year
# 								2010-2011</a> (pdf) <em>Added September 4, 2012</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/0910/Washington%20State%20School%20Personnel%20-%20School%20Year%202009-2010.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/0910/Washington%20State%20School%20Personnel%20-%20School%20Year%202009-2010.pdf">
# 								Washington State School Personnel - School Year
# 								2009-2010</a> (pdf) <em>Added September 4, 2012</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/0809/Washington%20State%20School%20Personnel%20-%20School%20Year%202008-2009.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/0809/Washington%20State%20School%20Personnel%20-%20School%20Year%202008-2009.pdf">
# 								Washington State School Personnel - School Year
# 								2008-2009 </a>(pdf) <em>Added September 4, 2012</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER/0708/Washington%20State%20School%20Personnel%20-%20School%20Year%202007-2008.pdf">
# 								<img alt="" class="style2" height="12" src="images/BD14868_.gif" width="12"/></a></td>
# 								<td>
# 								<a href="PUB/PER/0708/Washington%20State%20School%20Personnel%20-%20School%20Year%202007-2008.pdf">
# 								Washington State School Personnel - School Year
# 								2007-2008</a> (pdf) <em>Added September 4, 2012</em></td>
# 				</tr>
# 				<tr>
# 								<td>
# 								<a href="PUB/PER
# 					SY 2010-2011</a></b>(Updated 01/02/12) (For further information contact
# 	<a href="mailto:becky.mclean@k12.wa.us">Becky McLean</a> 360-725-6306)</td></tr>
# 	<tr><td><b><a href="rep/enr/0910/FTE%20HC%20Data%202009-10%20Enrollment.zip">Final Enrollment Data --Microsoft Excel
# 					SY 2009-2010</a></b>(Updated 12/06/10) (For further information contact
# 	<a href="mailto:becky.mclean@k12.wa.us">Becky McLean</a> 360-725-6306)</td></tr>
# 	<tr><td><b><a href="rep/enr/0809/FTE%20HC%20Data%202008-09%20Enrollment.zip">Final Enrollment Data --Microsoft Excel
# 					SY 2008-2009</a></b>(Updated 12/02/09) (For further information contact
# 	<a href="mailto:becky.mclean@k12.wa.us">Becky McLean</a> 360-725-6306)</td></tr>
# 	<tr><td><b><a href="rep/enr/0708/FTE%20HC%20Data%202007-08%20Enrollment.zip">Final Enrollment Data --Microsoft Excel
# 					SY 2007-2008</a> </b>(Updated 12/05/08) (For further information contact
# 	<a href="mailto:becky.mclean@k12.wa.us">Becky McLean</a> 360-725-6306)</td></tr>
#
#
# </tbody></table>
# <p class="style5">The following files were created in Microsoft Excel and contain the raw
# 		extract data reported on all Apportionment reports. The file has been zipped to conserve
# 		space. </p>
# <table style="width: 100%">
#
# 	<tbody><tr>
#
# 	<td><b><a href="rep/app/1718/1718%20Extract%20Files.zip">Current Extract -
# 					School Year 2017-2018 </a></b>(For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307) <em>
# 	Updated November 21, 2017</em></td></tr>
#
# 	<tr><td><b><a href="rep/app/1617/1617%20Extract%20Files.zip">Current Extract -
# 					School Year 2016-2017 </a></b>(For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307) <em>
# 	Updated August 25, 2017</em></td></tr>
# 	<tr><td><b><a href="rep/app/1516/1516%20Extract%20Files.zip">Final Extract -
# 					School Year 2015-2016 </a></b>(For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307) <em>
# 	Updated January 25, 2017</em></td></tr>
# 	<tr><td style="height: 20px"><b>Final Extract - <a href="rep/app/1415/1415%20Extract%20Files.zip">
# 					School Year 2014-2015 </a></b>(For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307) <em>
# 	Updated January 22, 2016</em></td></tr>
# 	<tr><td><b><a href="rep/app/1314/1314%20Extract%20Files.zip">Final Extract -
# 					School Year 2013-2014 </a></b>(For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307) <em>
# 	Updated January 29, 2015</em></td></tr>
# 	<tr><td><b><a href="rep/app/1213/1213%20Extract%20Files.zip">Final Extract -
# 					School Year 2012-2013  </a></b>(For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307)  <em>Updated August 11, 2014</em></td></tr>
# 	<tr><td><b><a href="rep/app/1112/1112%20Extract%20Files.zip">Final Extract -
# 					School Year 2011-2012</a></b> (For further information contact
# 	<a href="mailto:melissa.jarmon@k12.wa.us">Melissa Jarmon</a> 360-725-6307)  <em>Updated August 11, 2014</em></td></tr>
#
# </tbody></table>
# 	<div style="background-color: #FFFFFF">
# 		<br/>
# <table style="width: 100%">
# 				<tbody><tr>
# 								<td><b>
# 								<a href="Misc/I-1351 Staff Units.xls">
# 								Staffing Unit Comparison - Impact of I-1351</a> </b>(Updated
# 								11/04/14)</td>
# 				</tr>
#
#
# </tbody></table>
#
# 	<div style="background-color: #FFFFFF">
# 		<br/>
# <table style="width: 100%">
# 				<tbody><tr>
# 								<td><b>
# 								<a href="Misc/Vader Report.pdf">
# 								Vader Report</a> </b>(Posted 6/09/11)</td>
# 				</tr>
# <!--
# <table style="width: 100%">
# 				<tr><td>Right Here Steve
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/16levy.pdf">16LEVY</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/TABLE1.pdf">TABLE1</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/TABLE2.pdf">TABLE2</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/TABLE3.pdf">TABLE3</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/TABLE4.pdf">TABLE4</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/TABLE5.pdf">TABLE5</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/GFSUM.pdf">GFSUM</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/1463GF for Steve.pdf">1463GF</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/1463BI.pdf">1463BI</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/1463TVF.pdf">1463TVF</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/1463CP.pdf">1463CP</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/2010 for Steve.pdf">2010</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/1061 for Steve.pdf">1061</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/2030SUM.pdf">2030SUM</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/2030 for Steve.pdf">2030</a></b></tr>
# 				<tr><td><b><a href="rep/app/1516/2016 Levy Document Preview/CERTLEVY 2016.pdf">CertLevy</a></b></tr>
#
#
# </tr>
#
#
# -->
#
# </tbody></table>
#
# 		<br/>
#     	<li>
# 		<p>
#  [Updated - Octo<span class="style3">ber 24, 2017]</span><span style="background-color: #FFFFFF">
# <!-- END MAIN CONTENT HERE -->
#
#
# <style type="text/css">
# @import url('SAFStyle.css');
# .style1 {
# 				font-weight: bold;
# }
# </style>
#
#
#
#
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# 	<tbody><tr><td>
# 	<hr/></td></tr>
#
#
# 	   <tr><td> </td></tr>
# 			<tr><td>Director, School Apportionment and Financial Services:
# 				<a href="mailto:thomas.kelly@k12.wa.us">T.J. Kelly</a>
#             (360)725-6301
# 			</td></tr>
# 			<tr><td>Associate Director, School Apportionment and Financial Services:
# 				<a href="mailto:Michelle.Matakas@k12.wa.us">Michelle Matakas</a>
# 				(360)725-6019
# 				</td></tr>
# 	       <tr><td>Supervisor, SD/ESD Budget :
# 			<a href="mailto:mike.dooley@k12.wa.us">Mike Dooley </a>(360)725-6305
# 			</td></tr>
# 			<tr><td>
# 			Supervisor, SD/ESD Annual Financial Statements :
# 			<a href="mailto:ramona.garner@k12.wa.us">Ramona Garner</a> (360)725-6304
# 			</td></tr><tr><td>
# 			Supervisor, SD/ESD Accounting :
# 			<a href="mailto:paul.stone@k12.wa.us">Paul
# 			Stone</a>
# 			(360)725-6303
# 			</td></tr>
# 			<tr><td>
# 			Supervisor, Enrollment : <a href="mailto:becky.mclean@k12.wa.us">
# 			Becky McLean</a> (360)725-6306
# 			</td></tr>
# 			<tr><td>Supervisor, Apportionment Payments, Basic Ed Funding :
# 				<a href="mailto:melissa.jarmon@k12.wa.us">
# 							Melissa Jarmon</a> (360)725-6307</td></tr>
# 			<tr><td>
#             Supervisor, Personnel Reporting :
# 			<a href="mailto:ross.bunda@k12.wa.us">Ross Bunda</a>
#             (360)725-6308
# 			</td></tr>
# 			<tr><td>
# 			Apportionment Advances/Redirections :
# 			<a href="mailto:mike.dooley@k12.wa.us">Mike Dooley </a>(360)725-6305
# 			</td></tr>
#         	<tr><td> </td></tr>
# 		<tr><td>
# 		Office of Superintendent of Public Instruction<br/>
# 		School Apportionment &amp; Financial Services<br/>
# 		Old Capitol Building, PO Box 47200<br/>
# 		Olympia, WA 98504-7200<br/>
#         Phone:(360)725-6300    FAX:(360)664-3683    TDD:(360)664-3631
# 		</td></tr>
#
# 	<tr><td> </td></tr>
# 	<tr><td>
#         Web content in PDF format requires the <a href="http://www.adobe.com/products/acrobat/readstep2.html">Free
# 		Adobe PDF Reader</a>
# 	</td></tr>
# 	<tr><td><a href="/safs/default.asp">Apportionment &amp; Financial Services Home Page</a></td></tr>
# 	<tr><td>
#     <a href="#top">
# 	Go to Top</a></td></tr>
# </tbody></table>
#
# </span></p></li></div></div></td>
# </tr></tbody></table>
#
#
#
#
#
#
#
# <title></title>
#
#
#
#
# <table width="100%">
# 	<tbody><tr>
# 		<td width="100%">
# 			<hr/>
# 			<center>
# 			<font face="Arial" size="-2">
# 				<b>OSPI</b><br/>
# 				Old Capitol Building, P.O. Box 47200, Olympia, WA 98504-7200<br/>
# 				(360) 725-6000       TTY (360) 664-3631
#                 <a href="mailto:webmaster@k12.wa.us">webmaster@k12.wa.us</a>			</font>
# 			</center>
# 		</td>
# 	</tr>
# </tbody></table><table bgcolor="#061E50" border="0" cellpadding="0" cellspacing="0" width="100%">
#   <tbody><tr valign="middle">
# 	<td align="center" nowrap="">
# 		<font color="#FFFFFF" size="-2">
#
# 		</font>
# 	</td>
# <!--
#     <td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF"><a href="../index.asp">
# 		<img border="0" src="/images/redtabsl/Lredtab1.gif" WIDTH="60" HEIGHT="12" alt="Home"></a>
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		&nbsp; | &nbsp;
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		<img border="0" src="/images/redtabsl/Lredtab2.gif" WIDTH="75" HEIGHT="12" alt="OSPI Staff">
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		&nbsp; | &nbsp;
# 		</font>
# 	</td>
#     <td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		<img border="0" src="/images/redtabsl/Lredtab3.gif" WIDTH="100" HEIGHT="12" alt="District Directory">
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		&nbsp; | &nbsp;
# 		</font>
# 	</td>
#     <td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		<img border="0" src="/images/redtabsl/Lredtab4.gif" WIDTH="100" HEIGHT="12" alt="School Directory">
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		&nbsp; | &nbsp;
# 		</font>
# 	</td>
#     <td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		<img border="0" src="/images/redtabsl/Lredtab5.gif" WIDTH="70" HEIGHT="12" alt="Site Info">
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		&nbsp; | &nbsp;
# 		</font>
# 	</td>
#     <td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		<img border="0" src="/images/redtabsl/Lredtab6.gif" WIDTH="75" HEIGHT="12" alt="Site Search">
# 		</font>
# 	</td>
# 	<td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		&nbsp; | &nbsp;
# 		</font>
# 	</td>
#     <td align="center" noWrap>
# 		<font size="-2" color="#FFFFFF">
# 		<a href="/publications/">
# 			<img border="0" src="/images/redtabsl/Lredtab7.gif" border="0" WIDTH="75" HEIGHT="12" alt="Publications">
# 		</a>
# 		</font>
# 	</td>
# -->
#
#   </tr>
# </tbody></table>
# <!-- BEGIN LOW LEVEL TEXT FOOTER HERE -->
# <!--
# <table border="0" width="100%" style="BORDER-RIGHT-STYLE: solid" bgcolor="#ffffff" cellspacing="0" cellpadding="0" bordercolor="#ffffff">
#   <tr>
#     <td width=100%>
#       <p align="center">
# 		<font face="Arial" size="1" color="#0000000">
# 			<a href="/supt/">Superintendent's Office</a> |
# 			<a href="/">Administrative Information</a> |
# 			<a href="/academicinfo/">Academic Information</a> |
# 			<a href="/reform/">Education Reform</a> |
# 			<a href="/calendar/">Calendar</a> |
# 			<a href="/personnel/">Employment</a> |
# 			<a href="/search/">Search</a>
# 		</font>
# 	  </p>
#     </td>
#   </tr>
# </table>
# -->
# <!-- END LOW LEVEL TEXT FOOTER HERE -->
#
#
# </body></html>

# %% [markdown]
# ### Find all live links on web-site

# %%
links = soup.findAll('a')

# %% [markdown]
# #### only look at links that end with desired file type...in our case ".mdb" and ".accdb"...both access files

# %%
data_links = [data_url + link['href'] for link in links if link['href'].endswith(('.mdb', '.accdb'))]
print(data_links)
type(data_links)
# Out:
# ['http://www.k12.wa.us/safs/INS/MIS/aF1951617.accdb', 'http://www.k12.wa.us/safs/INS/MIS/Item%20Number%20Multiple%20Year.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1617/2016-2017_Preliminary_S-275_Personnel_Database.accdb', 'http://www.k12.wa.us/safs/PUB/PER/1617/2016-2017_Preliminary_S-275_Personnel_Database.accdb', 'http://www.k12.wa.us/safs/PUB/PER/1516/2015-2016_Final_S-275_Personnel_Database.accdb', 'http://www.k12.wa.us/safs/PUB/PER/1516/2015-2016_Final_S-275_Personnel_Database.accdb', 'http://www.k12.wa.us/safs/PUB/PER/1415/2014-2015S275FinalForPublic.accdb', 'http://www.k12.wa.us/safs/PUB/PER/1415/2014-2015S275FinalForPublic.accdb', 'http://www.k12.wa.us/safs/PUB/PER/1314/2013-2014S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1314/2013-2014S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1213/2012-2013S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1213/2012-2013S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1112/2011-2012S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1112/2011-2012S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1011/2010-2011S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/1011/2010-2011S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0910/2009-2010S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0910/2009-2010S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0809/2008-2009S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0809/2008-2009S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0708/2007-2008S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0708/2007-2008S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0607/2006-2007S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0607/2006-2007S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0506/2005-2006S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0506/2005-2006S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0405/2004-2005S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0405/2004-2005S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0304/2003-2004S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0304/2003-2004S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0203/2002-2003S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0203/2002-2003S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0102/2001-2002S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0102/2001-2002S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0001/2000-2001S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/0001/2000-2001S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9900/1999-2000S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9900/1999-2000S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9899/1998-1999S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9899/1998-1999S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9798/1997-1998S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9798/1997-1998S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9697/1996-1997S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9697/1996-1997S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9596/1995-1996S275FinalForPublic.mdb', 'http://www.k12.wa.us/safs/PUB/PER/9596/1995-1996S275FinalForPublic.mdb']
# list

# %% [markdown]
# ## Looks like there are duplicate links:
# ### HTML table contains two link and its extracting all of them, the following is a quick fix..

# %%
l=()
i = set(data_links) 
for x in i:
    link = str(x)       
    l+=(x,)
print(l)

# %% [markdown]
# ## Putting it all together by creating a function...

# %%
'''
URL of the OSPI web-page which provides link to
all the data files.
In this example, we first crawl the webpage to extract
all the links and then download the data.
'''
 
# specify the URL
data_url = "http://www.k12.wa.us/safs/"
archive_url = "http://www.k12.wa.us/safs/db.asp"

 
def get_data_links():
     
    # create response object
    r = requests.get(archive_url)
     
    # create beautiful-soup object
    soup = BeautifulSoup(r.content,'html5lib')
     
    # find all links on web-page
    links = soup.findAll('a')
 
    # filter the link sending with .mp4
    l_links = [data_url + link['href'] for link in links if link['href'].endswith(('.mdb', '.accdb'))]
    
    data_links=[]
    #remove the duplication...there must be a better way!
    i = set(l_links) 
    for x in i:
        link = str(x)       
        data_links+=(x,)
 
    return data_links

# %% [markdown]
# ## Let's try to create a loop to do the job...

# %%
link = get_data_links()   
type(link)
get_data_links()
# Out:
# ['http://www.k12.wa.us/safs/PUB/PER/1415/2014-2015S275FinalForPublic.accdb',
#  'http://www.k12.wa.us/safs/PUB/PER/1112/2011-2012S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0809/2008-2009S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/9596/1995-1996S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/INS/MIS/Item%20Number%20Multiple%20Year.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/1314/2013-2014S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/1213/2012-2013S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0203/2002-2003S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/9899/1998-1999S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0607/2006-2007S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/1516/2015-2016_Final_S-275_Personnel_Database.accdb',
#  'http://www.k12.wa.us/safs/INS/MIS/aF1951617.accdb',
#  'http://www.k12.wa.us/safs/PUB/PER/9900/1999-2000S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0102/2001-2002S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/1011/2010-2011S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/9798/1997-1998S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/9697/1996-1997S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0001/2000-2001S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0405/2004-2005S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0304/2003-2004S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/1617/2016-2017_Preliminary_S-275_Personnel_Database.accdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0506/2005-2006S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0708/2007-2008S275FinalForPublic.mdb',
#  'http://www.k12.wa.us/safs/PUB/PER/0910/2009-2010S275FinalForPublic.mdb']

# %%
#test = 'http://www.k12.wa.us/safs/PUB/PER/0405/2004-2005S275FinalForPublic.mdb'
#test.split('/')[-1]   
#'C:/Users/jhernandez/Documents/S275/'+test.split('/')[-1]
data_links = get_data_links()
type(data_links)
# Out:
# list

# %%
hd = 'C:/Users/jhernandez/Documents/S275/'
data_links = get_data_links()

for link in data_links:
 
        '''iterate through all links in data_links
        and download them one by one'''
         
        # 
        file_name = hd+link.split('/')[-1]   
 
        # 
        urllib.request.urlretrieve(link, file_name)
